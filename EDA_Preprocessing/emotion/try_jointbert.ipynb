# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/.shortcut-targets-by-id/1QTsxOPXs8iPJkgzYl7XDs3avs0JbY4pp/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA
# Out:
# /content/drive/.shortcut-targets-by-id/1QTsxOPXs8iPJkgzYl7XDs3avs0JbY4pp/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA

# %%
# import tensorflow.compat.v1 as tf
# #To make tf 2.0 compatible with tf1.0 code, we disable the tf2.0 functionalities
# tf.compat.v1.disable_eager_execution()

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 2.8.0

# %%
# !pip install tensorflow==1.15.0 # 정확한 버전 확인 필요
# Out:
# Collecting tensorflow==1.15.0
#   Downloading tensorflow-1.15.0-cp37-cp37m-manylinux2010_x86_64.whl (412.3 MB)
#      |████████████████████████████████| 412.3 MB 27 kB/s
# Collecting tensorboard<1.16.0,>=1.15.0
#   Downloading tensorboard-1.15.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 52.0 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.44.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.14.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.21.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (0.8.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (3.3.0)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 7.4 MB/s
# Collecting gast==0.2.2
#   Downloading gast-0.2.2.tar.gz (10 kB)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.0.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (0.2.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (3.17.3)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (1.1.2)
# Collecting tensorflow-estimator==1.15.1
#   Downloading tensorflow_estimator-1.15.1-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 56.4 MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.15.0) (0.37.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->tensorflow==1.15.0) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.3.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (57.4.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (1.0.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow==1.15.0) (4.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->tensorflow==1.15.0) (1.5.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=cca0de2829fa314a02c414fc34b92c41d7034b6a4273c0bf50c2bc8732b84455
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# Installing collected packages: tensorflow-estimator, tensorboard, keras-applications, gast, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.16.0 requires gast>=0.3.2, but you have gast 0.2.2 which is incompatible.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.15.0 which is incompatible.
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-1.15.0 tensorflow-1.15.0 tensorflow-estimator-1.15.1

# %% [markdown]
# > 위 과정 진행 이후 `런타임 다시 시작`

# %%
import tensorflow as tf

print(tf.__version__)
# Out:
# 1.15.0

# %%
cd /content/drive/.shortcut-targets-by-id/1QTsxOPXs8iPJkgzYl7XDs3avs0JbY4pp/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA
# Out:
# /content/drive/.shortcut-targets-by-id/1QTsxOPXs8iPJkgzYl7XDs3avs0JbY4pp/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA

# %%
ls
# Out:
# 0427yeon_ex.ipynb             layers/                    save_model/
# albert-module/                log                        test_pv.sh
# data/                         models/                    train_joint_bert.py
# data_text/                    prepare_data_mecab_bpe.py  tutorial
# eval_joint_bert_allsents.py   __pycache__/               utils.py
# eval_joint_bert_allsents.py~  readers/                   vectorizers/
# eval_joint_bert.py            README.md
# eval_joint_bert.py~           requirements.txt

# %%
from models.joint_bert import JointBertModel # models 폴더의 joint_bert.py 파일 안의 JointBertModel 클래스 불러오기

# %%
# import tensorflow.compat.v1 as tf
# #To make tf 2.0 compatible with tf1.0 code, we disable the tf2.0 functionalities
# tf.compat.v1.disable_eager_execution()

# %%
trained_PATH = '/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/save_model/epoch30'

# %%
# sess 에러
model = JointBertModel.load(trained_PATH)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a0211080ccae> in <module>()
#       1 # sess 에러
# ----> 2 model = JointBertModel.load(trained_PATH)
#
# TypeError: load() missing 1 required positional argument: 'sess'

# %%
# train_joint_bert.py 파일 안에 있음
config = tf.ConfigProto(intra_op_parallelism_threads=0, 
                        inter_op_parallelism_threads=0,
                        allow_soft_placement=True,
                        device_count = {'GPU': 1})
sess = tf.compat.v1.Session(config=config)

# %%
model = JointBertModel.load(trained_PATH, sess)
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# slots output : (?, ?, 2)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, None)]       0
# __________________________________________________________________________________________________
# input_masks (InputLayer)        [(None, None)]       0
# __________________________________________________________________________________________________
# segment_ids (InputLayer)        [(None, None)]       0
# __________________________________________________________________________________________________
# AlbertLayer (AlbertLayer)       ((None, 768), (None, 11812272    input_ids[0][0]
#                                                                  input_masks[0][0]
#                                                                  segment_ids[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 2)      1538        AlbertLayer[0][1]
# __________________________________________________________________________________________________
# intent_classifier (Dense)       (None, 6)            4614        AlbertLayer[0][0]
# ==================================================================================================
# Total params: 11,818,424
# Trainable params: 7,094,024
# Non-trainable params: 4,724,400
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-1dcc4ba1eb75> in <module>()
# ----> 1 model = JointBertModel.load(trained_PATH, sess)
#
# /content/drive/.shortcut-targets-by-id/1QTsxOPXs8iPJkgzYl7XDs3avs0JbY4pp/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/models/joint_bert.py in load(load_folder_path, sess)
#     209
#     210         new_model = JointBertModel(slots_num, intents_num, bert_hub_path, sess, num_bert_fine_tune_layers, is_bert, is_training=False)
# --> 211         new_model.model.load_weights(os.path.join(load_folder_path,'joint_bert_model.h5'))
#     212         return new_model
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/engine/training.py in load_weights(self, filepath, by_name)
#     180         raise ValueError('Load weights is not yet supported with TPUStrategy '
#     181                          'with steps_per_run greater than 1.')
# --> 182     return super(Model, self).load_weights(filepath, by_name)
#     183
#     184   @trackable.no_automatic_dependency_tracking
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/engine/network.py in load_weights(self, filepath, by_name)
#    1371         saving.load_weights_from_hdf5_group_by_name(f, self.layers)
#    1372       else:
# -> 1373         saving.load_weights_from_hdf5_group(f, self.layers)
#    1374
#    1375   def _updated_config(self):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/keras/saving/hdf5_format.py in load_weights_from_hdf5_group(f, layers)
#     643   """
#     644   if 'keras_version' in f.attrs:
# --> 645     original_keras_version = f.attrs['keras_version'].decode('utf8')
#     646   else:
#     647     original_keras_version = '1'
#
# AttributeError: 'str' object has no attribute 'decode'

# %% [markdown]
# > `decode()` -> `encode().decode('utf-8')`로 수정 후 `런타임 다시시작` 진행!

# %%
model = JointBertModel.load(trained_PATH, sess)
# Out:
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# slots output : (?, ?, 2)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, None)]       0
# __________________________________________________________________________________________________
# input_masks (InputLayer)        [(None, None)]       0
# __________________________________________________________________________________________________
# segment_ids (InputLayer)        [(None, None)]       0
# __________________________________________________________________________________________________
# AlbertLayer (AlbertLayer)       ((None, 768), (None, 11812272    input_ids[0][0]
#                                                                  input_masks[0][0]
#                                                                  segment_ids[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 2)      1538        AlbertLayer[0][1]
# __________________________________________________________________________________________________
# intent_classifier (Dense)       (None, 6)            4614        AlbertLayer[0][0]
# ==================================================================================================
# Total params: 11,818,424
# Trainable params: 7,094,024
# Non-trainable params: 4,724,400
# __________________________________________________________________________________________________

# %%
# 에러 -> eval_joint_ber.py 파일 사용하기
model.summary()

# %%
# !pip install sentencepiece==0.1.91 # requirements.txt 버전 참조
# Out:
# Collecting sentencepiece==0.1.91
#   Downloading sentencepiece-0.1.91-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 32.7 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.91

# %%
# read command-line parameters
parser = argparse.ArgumentParser('Evaluating the Joint BERT / ALBERT NLU model')
# parser.add_argument('--model', '-m', help = 'Path to joint BERT / ALBERT NLU model', type = str, required = True)
# parser.add_argument('--data', '-d', help = 'Path to data in Goo et al format', type = str, required = True)
# #parser.add_argument('--type', '-tp', help = 'bert   or    albert', type = str, default = 'bert', required = False)

parser
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-6bdf53b28352> in <module>()
#       1 # read command-line parameters
# ----> 2 parser = argparse.ArgumentParser('Evaluating the Joint BERT / ALBERT NLU model')
#       3 # parser.add_argument('--model', '-m', help = 'Path to joint BERT / ALBERT NLU model', type = str, required = True)
#       4 # parser.add_argument('--data', '-d', help = 'Path to data in Goo et al format', type = str, required = True)
#       5 # #parser.add_argument('--type', '-tp', help = 'bert   or    albert', type = str, default = 'bert', required = False)
#
# NameError: name 'argparse' is not defined

# %%
parser.parse_args()
# Out:
# usage: Evaluating the Joint BERT / ALBERT NLU model [-h] --model MODEL --data
#                                                     DATA
# Evaluating the Joint BERT / ALBERT NLU model: error: the following arguments are required: --model/-m, --data/-d
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# read command-line parameters
parser = argparse.ArgumentParser('Evaluating the Joint BERT / ALBERT NLU model')
parser.add_argument('--model', '-m', help='Path to joint BERT / ALBERT NLU model', type=str, required=True)
parser.add_argument('--data', '-d', help='Path to data in Goo et al format', type=str, required=True)
#parser.add_argument('--type', '-tp', help = 'bert   or    albert', type = str, default = 'bert', required = False)

parser

# %%
# argparse 버전 대신 easydict 버전으로?
import easydict

args = easydict.EasyDict({
    'model': False,
    'data': False
})

# %%
args
# Out:
# {'data': False, 'model': False}

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--batch_size', default=100, type=int, help='batch size')
parser.add_argument('--train_steps', default=1000, type=int,
                    help='number of training steps')
# Out:
# _StoreAction(option_strings=['--train_steps'], dest='train_steps', nargs=None, const=None, default=1000, type=<class 'int'>, choices=None, help='number of training steps', metavar=None)

# %%
parser.parse_args()
# Out:
# Namespace(batch_size=100, train_steps=1000)

# %%
import argparse
parser = argparse.ArgumentParser()
parser.parse_args()
# Out:
# usage: ipykernel_launcher.py [-h]
# ipykernel_launcher.py: error: unrecognized arguments: -f /root/.local/share/jupyter/runtime/kernel-c8ba776e-229c-4d6d-b562-e014bd48d953.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# train_joint_bert.py
parser = argparse.ArgumentParser('Training the Joint BERT NLU model')
parser.add_argument('--train', '-t', help='Path to training data in Goo et al format', type = str, required = True)
parser.add_argument('--val', '-v', help='Path to validation data in Goo et al format', type = str, default = "", required = False)
parser.add_argument('--save', '-s', help='Folder path to save the trained model', type = str, required = True)
parser.add_argument('--epochs', '-e', help='Number of epochs', type = int, default = 5, required = False)
parser.add_argument('--batch', '-bs', help='Batch size', type = int, default = 64, required = False)
#parser.add_argument('--type', '-tp', help='bert   or    albert', type = str, default = 'bert', required = False)
# Out:
# _StoreAction(option_strings=['--batch', '-bs'], dest='batch', nargs=None, const=None, default=64, type=<class 'int'>, choices=None, help='Batch size', metavar=None)

# %%
parser.parse_args()
# Out:
# usage: Training the Joint BERT NLU model [-h] --train TRAIN [--val VAL] --save
#                                          SAVE [--epochs EPOCHS]
#                                          [--batch BATCH]
# Training the Joint BERT NLU model: error: the following arguments are required: --train/-t, --save/-s
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
parser = argparse.ArgumentParser('Evaluating the Joint BERT / ALBERT NLU model')
parser.add_argument('--model', '-m', help='Path to joint BERT / ALBERT NLU model', type=str, required=False)
parser.add_argument('--data', '-d', help='Path to data in Goo et al format', type=str, required=False)
#parser.add_argument('--type', '-tp', help = 'bert   or    albert', type = str, default = 'bert', required = False)
parser
# Out:
# ArgumentParser(prog='Evaluating the Joint BERT / ALBERT NLU model', usage=None, description=None, formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)

# %%
parser = argparse.ArgumentParser('Evaluating the Joint BERT / ALBERT NLU model')
parser.add_argument('--model', '-m', help='Path to joint BERT / ALBERT NLU model', type=str, required=False)
parser.add_argument('--data', '-d', help='Path to data in Goo et al format', type=str, required=False)
#parser.add_argument('--type', '-tp', help = 'bert   or    albert', type = str, default = 'bert', required = False)

args = parser.parse_args(args=[])
args
# Out:
# Namespace(data=None, model=None)

# %%
args.model = '/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/models'
args.data = '/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/readers/goo_format_reader.py'
args
# Out:
# Namespace(data='/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/readers/goo_format_reader.py', model='/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/models')

# %%
# !pip install readers
# Out:
# Collecting readers
#   Downloading readers-1.0.tar.gz (793 bytes)
# WARNING: Discarding https://files.pythonhosted.org/packages/f4/78/89d6a8859e7961a79433befa2147f60b8c7f8a06173529b1fdc1cdc0a12a/readers-1.0.tar.gz#sha256=4abe7ba3a1a473c0c28c50546023f25430a8ed630843e27f170f286939be1015 (from https://pypi.org/simple/readers/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading readers-0.1.3.tar.gz (797 bytes)
# WARNING: Discarding https://files.pythonhosted.org/packages/39/a3/87578998e82245bf36edafe792635b265d65f7794d42462d4220baf0e305/readers-0.1.3.tar.gz#sha256=eb121c83e88bcea529ea1b6f17cee07a0bc03078581b8f970cda15a294882b71 (from https://pypi.org/simple/readers/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading readers-0.1.2.tar.gz (772 bytes)
# Building wheels for collected packages: readers
#   Building wheel for readers (setup.py) ... done
#   Created wheel for readers: filename=readers-0.1.2-py3-none-any.whl size=1315 sha256=8e0f6d17b2d76651b1f9918f43549a8bf7fe98207aa81b1b1a873d2c04f71bb5
#   Stored in directory: /root/.cache/pip/wheels/bb/e7/bf/5146b49f4e9fa891887465b59ef457519fcaf7ec0664ecec87
# Successfully built readers
# Installing collected packages: readers
# Successfully installed readers-0.1.2

# %%
# !pip install file-readers
# Out:
# Requirement already satisfied: file-readers in /usr/local/lib/python3.7/dist-packages (0.0.9)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (from file-readers) (3.0.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl->file-readers) (1.1.0)

# %%
# eval_joint_bert.py
from readers.goo_format_reader import Reader
from vectorizers.bert_vectorizer import BERTVectorizer
from vectorizers.tags_vectorizer import TagsVectorizer
from vectorizers import albert_tokenization


import sklearn.metrics as metrics


import argparse
import easydict

# read command-line parameters
# parser = argparse.ArgumentParser('Evaluating the Joint BERT / ALBERT NLU model')
# parser.add_argument('--model', '-m', help='Path to joint BERT / ALBERT NLU model', type=str, required=True)
# parser.add_argument('--data', '-d', help='Path to data in Goo et al format', type=str, required=True)
# #parser.add_argument('--type', '-tp', help = 'bert   or    albert', type = str, default = 'bert', required = False)


# args = easydict.EasyDict({
#     'model': False,
#     'data': False
# })


parser = argparse.ArgumentParser('Evaluating the Joint BERT / ALBERT NLU model')
parser.add_argument('--model', '-m', help='Path to joint BERT / ALBERT NLU model', type=str, required=False) # False로 변환
parser.add_argument('--data', '-d', help='Path to data in Goo et al format', type=str, required=False) # False로 변환
#parser.add_argument('--type', '-tp', help = 'bert   or    albert', type = str, default = 'bert', required = False)

args = parser.parse_args(args=[])
args.model = '/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/models'
args.data = '/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/data/train'
# args

# args = parser.parse_args()
load_folder_path = args.model
data_folder_path = args.data

bert_model_hub_path = '/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/albert-module'
is_bert = False
tokenizer = albert_tokenization.FullTokenizer('/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/albert-module/assets/v0.vocab')
bert_vectorizer = BERTVectorizer(sess, is_bert, bert_model_hub_path)


# data_text_arr, data_tags_arr, data_intents = Reader.read(data_folder_path)
data_text_arr, data_tags_arr, data_intents = Reader.read_allsents(data_folder_path)
data_input_ids, data_input_mask, data_segment_ids, data_sequence_lengths = bert_vectorizer.transform(data_text_arr)

tags_vectorizer = TagsVectorizer()
tags_vectorizer.fit(data_tags_arr)
data_tags_arr = tags_vectorizer.transform(data_tags_arr, data_input_ids)

#print(data_tags_arr[1])
#print(data_input_ids[1])

def get_results(input_ids, input_mask, segment_ids,  sequence_lengths, tags_arr,
                intents, tags_vectorizer, intents_label_encoder):
    inferred_tags, first_inferred_intent, first_inferred_intent_score, _, _, slots_score = model.predict_slots_intent([input_ids, input_mask, segment_ids], tags_vectorizer, intents_label_encoder)
    gold_tags = tags_vectorizer.simple_inverse_transform(tags_arr.astype(int), input_ids)
    #print(inferred_tags[1])
    #print(gold_tags[1])
    acc = metrics.accuracy_score(intents, first_inferred_intent)
    tag_incorrect = ''
    intent_incorrect = ''
    intent_correct = ''

    for i, sent in enumerate(input_ids):
        if intents[i] != first_inferred_intent[i]:
            tokens = tokenizer.convert_ids_to_tokens(input_ids[i])
            intent_incorrect += ('sent {}\n'.format(tokens))
            intent_incorrect += ('pred: {}\n'.format(first_inferred_intent[i].strip()))
            intent_incorrect += ('score: {}\n'.format(first_inferred_intent_score[i]))
            intent_incorrect += ('ansr: {}\n'.format(intents[i].strip()))
        else:
            tokens = tokenizer.convert_ids_to_tokens(input_ids[i])
            intent_correct += ('sent {}\n'.format(tokens))
            intent_correct += ('pred: {}\n'.format(first_inferred_intent[i].strip()))
            intent_correct += ('score: {}\n'.format(first_inferred_intent_score[i]))
            intent_correct += ('ansr: {}\n'.format(intents[i].strip()))


    # f1_score
    global positive_value
    positive_value = 0.5
    pv = positive_value
    tp = 0
    tn = 0
    fp = 0
    fn = 0

    tp_sents = ''
    tn_sents = ''
    fp_sents = ''
    fn_sents = ''

    for i in range(len(intents)):
        if first_inferred_intent[i] == intents[i] and first_inferred_intent_score[i] >= pv:
                tp += 1
                tp_sents += ('sent {}\n'.format(tokens))
                tp_sents += ('pred: {}\n'.format(first_inferred_intent[i].strip()))
                tp_sents += ('score: {}\n'.format(first_inferred_intent_score[i]))
                tp_sents += ('ansr: {}\n'.format(intents[i].strip()))

        elif first_inferred_intent[i] != intents[i] and first_inferred_intent_score[i] >= pv:
                fp += 1
                fp_sents += ('sent {}\n'.format(tokens))
                fp_sents += ('pred: {}\n'.format(first_inferred_intent[i].strip()))
                fp_sents += ('score: {}\n'.format(first_inferred_intent_score[i]))
                fp_sents += ('ansr: {}\n'.format(intents[i].strip()))

        elif first_inferred_intent[i] == intents[i] and first_inferred_intent_score[i] < pv:
                fn += 1
                fn_sents += ('sent {}\n'.format(tokens))
                fn_sents += ('pred: {}\n'.format(first_inferred_intent[i].strip()))
                fn_sents += ('score: {}\n'.format(first_inferred_intent_score[i]))
                fn_sents += ('ansr: {}\n'.format(intents[i].strip()))

        elif first_inferred_intent[i] != intents[i] and first_inferred_intent_score[i] < pv:
                tn += 1
                tn_sents += ('sent {}\n'.format(tokens))
                tn_sents += ('pred: {}\n'.format(first_inferred_intent[i].strip()))
                tn_sents += ('score: {}\n'.format(first_inferred_intent_score[i]))
                tn_sents += ('ansr: {}\n'.format(intents[i].strip()))

    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1_score = 2 * (precision * recall) / (precision + recall)
    f1_score = round(f1_score, 3)
    precision = round(precision, 3)
    recall = round(recall, 3)

    return f1_score, precision, recall, acc, intent_incorrect, intent_correct, tp, tn, fp, fn, tp_sents, tn_sents, fp_sents, fn_sents
# Out:
# initializing!
# sess : <tensorflow.python.client.session.Session object at 0x7f8d0caeba50>
# is_bert : False
# bert_model_hub_path : /content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/albert-module
# initialized!
# transform started
# /content/drive/.shortcut-targets-by-id/1QTsxOPXs8iPJkgzYl7XDs3avs0JbY4pp/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/vectorizers/tags_vectorizer.py:41: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data = np.array(data)

# %%
import pickle
import os

with open('/content/drive/MyDrive/AIFFELTHON/AIHub감성대화_Data/AI 모델/최종모델링/NIA/save_model/epoch30/intents_label_encoder.pkl', 'rb') as handle:
    intents_label_encoder = pickle.load(handle)
    intents_num = len(intents_label_encoder.classes_)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:338: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.23.1 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   UserWarning,

# %%
print('==== Evaluation ====')
f1_score, precision, recall, acc, intent_incorrect, intent_correct, tp, tn, fp, fn, tp_sents, tn_sents, fp_sents, fn_sents = get_results(
                                                            data_input_ids, 
                                                            data_input_mask, 
                                                            data_segment_ids,
                                                            data_sequence_lengths,
                                                            data_tags_arr, 
                                                            data_intents, 
                                                            tags_vectorizer, 
                                                            intents_label_encoder)
# Out:
# ==== Evaluation ====

# %%
print(f1_score, precision, recall, acc)
# Out:
# 0.77 0.63 0.992 0.6215580341582433

# %%
print(intent_incorrect, intent_correct)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(tp, tn, fp, fn)
# Out:
# 28298 740 16632 234

# %%
tp_sents

# %%
tn_sents
# Out:
# "sent ['[CLS]', '아', '무', '리', '생', '각', '해', '도', '내', '친', '구', '들', '중', '에', '내', '가', '제', '일', '잘', '생', '긴', '것', '같', '아', '.', '<unk>', '스', '스로', '잘', '생', '겼', '다고', '생', '각', '하', '시', '는', '군', '요', '.', '잘', '생', '기', '셨', '나', '봐', '요', '.', '<unk>', '내', '친', '구', '들', '도', '잘', '생', '겼', '지만', '특별', '히', '나', '는', '더', '잘', '생', '긴', '것', '같', '아', '.', '<unk>', '매', '우', '잘', '생', '기', '셨', '나', '보', '군', '요', '.', '평', '소', '에', '도', '많', '이', '그', '런', '소리', '를', '듣', '나', '요', '?', '<unk>', '내', '가', '잘', '생', '긴', '건', '세', '상', '이', '다', '알', '아', '.', '난', '그래', '서', '늘', '행', '복', '하', '지', '.', '<unk>', '잘', '생', '긴', '것', '이', '행', '복', '하', '다고', '느', '끼', '는', '이', '유', '는', '무', '엇', '인', '가', '요', '?', '[SEP]', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']\npred: 5\nscore: 0.47019389271736145\nansr: 0\nsent ['[CLS]', '아', '무', '리', '생', '각', '해', '도', '내', '친', '구', '들', '중', '에', '내', '가', '제', '일', '잘', '생', '긴', '것', '같', '아', '.', '<unk>', '스', '스로', '잘', '생', '겼', '다고', '생', '각', '하', '시', '는', '군', '요', '.', '잘', '생', '기', '셨', '나', '봐', '요', '.', '<unk>', '내', '친', '구', '들', '도', '잘', '생', '겼', '지만', '특별', '히', '나', '는', '더', '잘', '생', '긴', '것', '같', '아', '.', '<unk>', '매', '우', '잘', '생', '기', '셨', '나', '보', '군', '요', '.', '평', '소', '에', '도', '많', '이', '그', '런', '소리', '를', '듣', '나', '요', '?', '<unk>', '내', '가', '잘', '생', '긴', '건', '세', '상', '이', '다', '알', '아', '.', '난', '그래', '서', '늘', '행', '복', '하', '지', '.', '<unk>', '잘', '생', '긴', '것', '이', '행', '복', '하', '다고', '느', '끼', '는', '이', '유', '는', '무', '엇', '인', '가', '요', '?', '[SEP]', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '< ...

# %%
fp_sents

# %%
fn_sents
# Out:
# "sent ['[CLS]', '아', '무', '리', '생', '각', '해', '도', '내', '친', '구', '들', '중', '에', '내', '가', '제', '일', '잘', '생', '긴', '것', '같', '아', '.', '<unk>', '스', '스로', '잘', '생', '겼', '다고', '생', '각', '하', '시', '는', '군', '요', '.', '잘', '생', '기', '셨', '나', '봐', '요', '.', '<unk>', '내', '친', '구', '들', '도', '잘', '생', '겼', '지만', '특별', '히', '나', '는', '더', '잘', '생', '긴', '것', '같', '아', '.', '<unk>', '매', '우', '잘', '생', '기', '셨', '나', '보', '군', '요', '.', '평', '소', '에', '도', '많', '이', '그', '런', '소리', '를', '듣', '나', '요', '?', '<unk>', '내', '가', '잘', '생', '긴', '건', '세', '상', '이', '다', '알', '아', '.', '난', '그래', '서', '늘', '행', '복', '하', '지', '.', '<unk>', '잘', '생', '긴', '것', '이', '행', '복', '하', '다고', '느', '끼', '는', '이', '유', '는', '무', '엇', '인', '가', '요', '?', '[SEP]', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>']\npred: 0\nscore: 0.3996369540691376\nansr: 0\nsent ['[CLS]', '아', '무', '리', '생', '각', '해', '도', '내', '친', '구', '들', '중', '에', '내', '가', '제', '일', '잘', '생', '긴', '것', '같', '아', '.', '<unk>', '스', '스로', '잘', '생', '겼', '다고', '생', '각', '하', '시', '는', '군', '요', '.', '잘', '생', '기', '셨', '나', '봐', '요', '.', '<unk>', '내', '친', '구', '들', '도', '잘', '생', '겼', '지만', '특별', '히', '나', '는', '더', '잘', '생', '긴', '것', '같', '아', '.', '<unk>', '매', '우', '잘', '생', '기', '셨', '나', '보', '군', '요', '.', '평', '소', '에', '도', '많', '이', '그', '런', '소리', '를', '듣', '나', '요', '?', '<unk>', '내', '가', '잘', '생', '긴', '건', '세', '상', '이', '다', '알', '아', '.', '난', '그래', '서', '늘', '행', '복', '하', '지', '.', '<unk>', '잘', '생', '긴', '것', '이', '행', '복', '하', '다고', '느', '끼', '는', '이', '유', '는', '무', '엇', '인', '가', '요', '?', '[SEP]', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<pad>', '<p ...

# %%
tp
# Out:
# 28298

# %% [markdown]
# FAQ -> 분류 / dialog flow에 감정 분석이 들어가는지도 확인해보면 좋을 것 같다.
